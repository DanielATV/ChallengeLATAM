# %%
#librerias
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## ¿Cómo se distribuyen los datos? ¿Qué te llama la atención o cuál es tu conclusión sobre esto?

# %%
#data input
df = pd.read_csv('dataset_SCL.csv')
df.shape
# Out:
# /tmp/ipykernel_3451/813140826.py:2: DtypeWarning: Columns (1,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('dataset_SCL.csv')
# (68206, 18)

# %% [markdown]
# Para visualizar las distribuciones de los datos se un histograma para cada variable.

# %%
df.columns
# Out:
# Index(['Fecha-I', 'Vlo-I', 'Ori-I', 'Des-I', 'Emp-I', 'Fecha-O', 'Vlo-O',
#        'Ori-O', 'Des-O', 'Emp-O', 'DIA', 'MES', 'AÑO', 'DIANOM', 'TIPOVUELO',
#        'OPERA', 'SIGLAORI', 'SIGLADES'],
#       dtype='object')

# %%
#Numero de vuelo programado
df['Vlo-I'].value_counts()
# Out:
# 174     686
# 11      645
# 116     608
# 150     557
# 162     553
#        ...
# 1158      1
# 368       1
# 9955      1
# 9701      1
# 1218      1
# Name: Vlo-I, Length: 750, dtype: int64

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.histplot(ax=ax,data= df['Vlo-I'].astype(str))
plt.show()

# %% [markdown]
# Graficamente se ve hay números de vuelo con una frecuencia significativamente mayor a otros.

# %%
#codigo de ciudad de origen
df['Ori-I'].value_counts()
# Out:
# SCEL    68206
# Name: Ori-I, dtype: int64

# %% [markdown]
# En este caso como todos los vuelos parten del mismo lugar, no tiene sentido analizarlo visualmente.

# %%
#codigo de ciudad de origen
df['Des-I'].value_counts()
# Out:
# SCFA    5787
# SPJC    5270
# SCCF    5145
# SCTE    4357
# SCIE    3995
#         ...
# SBFI       1
# SPSO       1
# SEQU       1
# SEQM       1
# SARI       1
# Name: Des-I, Length: 64, dtype: int64

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.histplot(ax=ax,data= df['Des-I'].astype(str))
plt.show()

# %% [markdown]
# En el gráfico se ve que hay destinos que tienen una frecuencia muy superior en comparación con el resto.

# %%
#codigo aerolinea de vuelo
df['Emp-I'].value_counts()
# Out:
# LAN    37611
# SKU    14298
# TAM     3049
# ARG     1949
# CMP     1850
# LAW     1574
# AVA     1152
# JAT     1095
# GLO      806
# AAL      757
# ACA      565
# IBE      362
# AFR      358
# DAL      358
# AMX      351
# UAL      335
# ONE      279
# AZA      259
# KLM      251
# LAP      216
# BAW      205
# QFU      195
# JMR      100
# LRC       92
# AUT       74
# PUE       49
# LXP        9
# LPE        4
# DSM        2
# LNE        1
# Name: Emp-I, dtype: int64

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.histplot(ax=ax,data= df['Emp-I'].astype(str))
plt.show()

# %% [markdown]
# En el gráfico se ve que la distrubucion de las aerolineas estan concentradas principalmente en 2 de ellas LAN y SKU.

# %%
#numero de vuelo de operacion de vuelo
df['Vlo-O'].value_counts()
# Out:
# 174      649
# 11       646
# 116      608
# 150      517
# 704      514
#         ...
# 356        1
# 1148       1
# 846A       1
# 4950       1
# 180.0      1
# Name: Vlo-O, Length: 866, dtype: int64

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.histplot(ax=ax,data= df['Vlo-O'].astype(str))
plt.show()

# %% [markdown]
# En el gráfico, al igual que con el numero de vuelo programado, se ve que la frecuencia de algunos de los codigos es significativamente mayor al resto.

# %%
#codigo ciudad de origen de operacion
df['Ori-O'].value_counts()
# Out:
# SCEL    68206
# Name: Ori-O, dtype: int64

# %% [markdown]
# Puesto que todos los vuelos tienen el mismo origen no tiene sentido analizar la distrubicion de esta variable.

# %%
#codigo de ciudad de destino de operación.
df['Des-O'].value_counts()
# Out:
# SCFA    5786
# SPJC    5270
# SCCF    5146
# SCTE    4357
# SCIE    3993
#         ...
# SEQM       2
# KIAD       1
# SPSO       1
# EGYP       1
# SLCB       1
# Name: Des-O, Length: 63, dtype: int64

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.histplot(ax=ax,data= df['Des-O'].astype(str))
plt.show()

# %% [markdown]
# En la distruicion de los codigos de las ciudades de destino se ve que los valores estan mas distrubidos, pero aun hay variables con una frecuencia muy baja.

# %%
#codigo aerolínea de vuelo operado.
df['Emp-O'].value_counts()
# Out:
# LAN    20988
# LXP    14558
# SKU    14298
# TAM     3046
# ARG     1946
# CMP     1850
# JMR     1647
# LPE     1214
# JAT     1095
# AVA      885
# GLO      806
# AAL      757
# ACA      565
# DSM      493
# LNE      374
# IBE      362
# AFR      358
# DAL      358
# LRC      357
# AMX      351
# UAL      335
# ONE      279
# AZA      259
# KLM      251
# LAP      219
# BAW      205
# QFA      195
# AUT       77
# PUE       49
# 56R       17
# 48O       10
# TPU        2
# Name: Emp-O, dtype: int64

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.histplot(ax=ax,data= df['Emp-O'].astype(str))
plt.show()

# %% [markdown]
# En gráfico se ve que la gran mayoria de los vuelos son realizados por 3 aerolineas: LAN,LXP y SKU.

# %%
#Día del mes de operación del vuelo.
df['DIA'].value_counts()
# Out:
# 20    2290
# 27    2286
# 12    2284
# 10    2283
# 6     2275
# 22    2272
# 13    2272
# 3     2271
# 16    2268
# 26    2267
# 21    2267
# 7     2264
# 23    2260
# 5     2241
# 15    2239
# 19    2238
# 11    2237
# 24    2232
# 28    2232
# 17    2228
# 9     2227
# 2     2223
# 14    2221
# 4     2215
# 8     2213
# 1     2208
# 25    2179
# 18    2160
# 29    2044
# 30    2020
# 31    1290
# Name: DIA, dtype: int64

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.histplot(ax=ax,data= df['DIA'].astype(str))
plt.show()

# %% [markdown]
# En el gráfico se ve que la distribucion de los dias de los vuelos es principalmente homogenea exceptuando el dia 31. Esto quizas se explica puesto que no todos los meses tienen 31 días.

# %%
#Número de mes de operación del vuelo.
df['MES'].value_counts()
# Out:
# 12    6356
# 1     6108
# 11    6080
# 10    6032
# 7     5992
# 8     5744
# 9     5610
# 2     5561
# 3     5482
# 5     5240
# 4     5020
# 6     4981
# Name: MES, dtype: int64

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.histplot(ax=ax,data= df['MES'].astype(str))
plt.show()

# %% [markdown]
# En el gráfico se ve que al igual que los días se ve que la distribucion es principalmente homonegea, donde se ve que en los meses 4, 5 y 6 hay una menor frecuencia de vuelos.

# %%
#Año de operación del vuelo.
df['AÑO'].value_counts()
# Out:
# 2017    68204
# 2018        2
# Name: AÑO, dtype: int64

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.histplot(ax=ax,data= df['AÑO'].astype(str))
plt.show()

# %% [markdown]
# En el gráfico se ve que la casi todos los vuelos fueron realizados en el 2017.

# %%
#Día de la semana de operación del vuelo.
df['DIANOM'].value_counts()
# Out:
# Viernes      10292
# Jueves       10251
# Lunes        10131
# Domingo       9796
# Miercoles     9722
# Martes        9662
# Sabado        8352
# Name: DIANOM, dtype: int64

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.histplot(ax=ax,data= df['DIANOM'].astype(str))
plt.show()

# %% [markdown]
# En el gráfico se ve que la distribucion de vuelos por dias es mayoritariamente homogenea, exceptuando el dia sábado que tiene una menor frecuancia de vuelos en comparación a los otros dias.

# %%
#Tipo de vuelo, I =Internacional, N =Nacional.
df['TIPOVUELO'].value_counts()
# Out:
# N    36966
# I    31240
# Name: TIPOVUELO, dtype: int64

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.histplot(ax=ax,data= df['TIPOVUELO'].astype(str))
plt.show()

# %% [markdown]
# En el gráfico se ve que hay un mayor frecuencia de vuelos nacionales que internacionales. Esta diferencia es de alrededor de 5000 vuelos.

# %%
#Nombre de aerolínea que opera.
df['OPERA'].value_counts()
# Out:
# Grupo LATAM                 40892
# Sky Airline                 14298
# Aerolineas Argentinas        1949
# Copa Air                     1850
# Latin American Wings         1674
# Avianca                      1152
# JetSmart SPA                 1095
# Gol Trans                     806
# American Airlines             757
# Air Canada                    565
# Iberia                        362
# Delta Air                     358
# Air France                    358
# Aeromexico                    351
# United Airlines               335
# Oceanair Linhas Aereas        279
# Alitalia                      259
# K.L.M.                        251
# British Airways               205
# Qantas Airways                195
# Lacsa                          92
# Austral                        74
# Plus Ultra Lineas Aereas       49
# Name: OPERA, dtype: int64

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.histplot(ax=ax,data= df['OPERA'].astype(str))
plt.show()

# %% [markdown]
# En el gráfico se ve que la gran mayoria de los vuelos estan concetrados en dos aerolineas Grupo LATAM y Sky Airline.

# %%
#Nombre ciudad origen.
df['SIGLAORI'].value_counts()
# Out:
# Santiago    68206
# Name: SIGLAORI, dtype: int64

# %% [markdown]
# En caso de esta variable, de nuevo, como todos los vuelos parten del mismo lugar solamente tiene un valor y no tiene sentido el análisis.

# %%
#Nombre ciudad destino.
df['SIGLADES'].value_counts()
# Out:
# Buenos Aires      6335
# Antofagasta       5786
# Lima              5270
# Calama            5146
# Puerto Montt      4357
#                   ...
# Quito                2
# Washington           1
# Pisco, Peru          1
# Puerto Stanley       1
# Cochabamba           1
# Name: SIGLADES, Length: 62, dtype: int64

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.histplot(ax=ax,data= df['SIGLADES'].astype(str))
plt.show()

# %% [markdown]
# En el gráfico se ve que algunas ciudades tienen una frecuencia de vuelos mucho mayor en comparación con el resto.
